# %%
import pandas as pd
import tweepy

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAAOR%2BbwEAAAAASwiLtwOgXt%2FtG0EJIrLdaph2Xsw%3DspW7CHN0I6KBcjdy4BVvj75LpMAdgQ5l3DIkrcVWMFz8FLIHlz"

client = tweepy.Client(bearer_token, wait_on_rate_limit=True)

# %%
user = client.get_user(username='EnBW')
user_str = str(user)

print(user.data.id)
# Out:
# 12786932

# %%
user_id = "12786932"
response = client.get_users_followers(user_id, max_results=1000, pagination_token="J8LHR5RQGHUHEZZZ")

print(response)
# Out:
# Response(data=[<User id=3103861192 name=hero-news username=held_news>, <User id=74707609 name=Hydrogen Energy username=HydrogenEnergy>, <User id=1354758862721712133 name=h2-well username=h2_well>, <User id=318277594 name=Bernd Ziggel username=BerndZiggel>, <User id=1363751089552699392 name=Wolle Ruess username=WolleRuess>, <User id=1363179148794093570 name=Four Track Mind username=FourTrackMindUK>, <User id=2635436152 name=Alex Arnoldt username=AlexArnoldt>, <User id=1362548004536922113 name=Armani username=ArmanPTTS>, <User id=1331529457937551360 name=DLR_Energie username=DLR_Energie>, <User id=1364167135606558723 name=PietF username=PietFeldmann>, <User id=958624051500593152 name=Franco-German Forum- Deutsch-Französisches Forum username=AllemandForum>, <User id=820788197286408192 name=Yuzhuo Fu username=YuzhuoFu>, <User id=1299347658293809153 name=Lukas ''Benjiro'' H. username=twitchNebbich>, <User id=4164601827 name=Andre699799 username=Andre699799A>, <User id=21209104 name=Şefik 
# ...

# %%
user = client.get_user(username='_Katja_Diehl_')
user_str = str(user)

print(user.data.id)
# Out:
# 103121268
