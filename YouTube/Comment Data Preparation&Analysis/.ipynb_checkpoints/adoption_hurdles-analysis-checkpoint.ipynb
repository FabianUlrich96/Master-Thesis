# %%
import pandas as pd
import tmplot as tmp
import matplotlib.dates as md
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime
from statistics import mean
from statsmodels.tsa.stattools import adfuller
sns.set_theme(palette="pastel")
import json
from flatten_json import flatten

# %%
work_dir = "C:/Users/fabia/OneDrive - Otto-Friedrich-Universität Bamberg/Master/Masterarbeit/Data"

# %%
with open(work_dir + "/Comment/comments-adaption-hurdles.json", encoding="utf8") as json_file:
    data = json.load(json_file)

data_list = []
i = 0
for entry in data:
    flatten_data = flatten(data[i])
    try:
        choice_0 = flatten_data["annotations_0_result_0_value_choices_0"]
    except:
        choice_0 = False
    try:
        choice_1 = flatten_data["annotations_0_result_0_value_choices_1"]
    except:
        choice_1 = False
    try:
        choice_2 = flatten_data["annotations_0_result_0_value_choices_2"]
    except:
        choice_2 = False
    try:
        choice_3 = flatten_data["annotations_0_result_0_value_choices_3"]
    except:
        choice_3 = False
    try:
        choice_4 = flatten_data["annotations_0_result_0_value_choices_4"]
    except:
        choice_4 = False
    try:
        choice_5 = flatten_data["annotations_0_result_0_value_choices_5"]
    except:
        choice_5 = False
    try:
        choice_6 = flatten_data["annotations_0_result_0_value_choices_6"]
    except:
        choice_6 = False
    
    if choice_0 is not False:
        temp_list = [choice_0, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_1 is not False:
        temp_list = [choice_1, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_2 is not False:
        temp_list = [choice_2, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_3 is not False:
        temp_list = [choice_3, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_4 is not False:
        temp_list = [choice_4, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_5 is not False:
        temp_list = [choice_5, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_6 is not False:
        temp_list = [choice_6, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    i = i + 1

# %%
print(data_list)
# Out:
# [['Electricity price', '2021-05-25T20:10:48Z', 'UgzmfkeUgGimgM30FQh4AaABAg'], ['Other', '2021-05-04T16:00:31Z', 'UgwUIBdvTpLvXHr5S5t4AaABAg'], ['EV price', '2021-05-04T16:00:31Z', 'UgwUIBdvTpLvXHr5S5t4AaABAg'], ['None', '2021-10-10T07:45:02Z', 'Ugx6x6UQB0IW0oR8wfR4AaABAg'], ['Service problems', '2022-01-10T09:40:46Z', 'UgwmzlwoVWwo4Tgj96J4AaABAg'], ['Service problems', '2022-01-10T09:40:46Z', 'Ugyj9KU84hD_Pv3NECd4AaABAg'], ['Other', '2022-02-11T17:29:35Z', 'UgzGsGxoF2JSJtC16wN4AaABAg'], ['Service problems', '2022-02-25T15:30:07Z', 'Ugw5dI7Tzq_rJAECzW94AaABAg'], ['Habbit', '2020-07-24T16:00:00Z', 'Ugzr8TNGdXgSart0Oud4AaABAg'], ['None', '2020-07-15T07:03:15Z', 'Ugxez6h3F3z_Djzc3aJ4AaABAg'], ['Other', '2021-07-16T14:11:25Z', 'UgwNEU0YfKQzjC_hWkd4AaABAg'], ['Energy supply', '2021-07-16T14:11:25Z', 'UgwNEU0YfKQzjC_hWkd4AaABAg'], ['None', '2020-08-18T17:19:32Z', 'UgzM-OjMzR4KwjIOVQV4AaABAg'], ['Other', '2020-10-18T08:00:04Z', 'UgzBqNXQzPtIxiBHv8t4AaABAg'], ['None', '2020-11-27T16:46:54Z', 'UgwRB
:19:04Z', 'UgxtlBlwP8VEQ4EASlh4AaABAg'], ['Habbit', '2021-10-28T16:00:11Z', 'UgzuLTuE6CinwUVBCj14AaABAg'], ['None', '2021-10-22T16:00:30Z', 'UgzlRap7g_Yj-OsMlNp4AaABAg'], ['None', '2021-12-05T07:00:03Z', 'UgyFrcso3-T-QYCnHnJ4AaABAg'], ['None', '2022-01-16T16:00:14Z', 'Ugx_i2XLh0-DLtiJ1W54AaABAg'], ['Other', '2021-12-07T17:15:38Z', 'Ugyo7YabwG0Sg2_33Lx4AaABAg'], ['Charging infrastructure availability national', '2021-12-07T17:15:38Z', 'Ugyo7YabwG0Sg2_33Lx4AaABAg'], ['Range anxiety', '2021-12-07T17:15:38Z', 'Ugyo7YabwG0Sg2_33Lx4AaABAg'], ['None', '2022-01-11T16:55:24Z', 'Ugx7_LFJ8jMkpdQ8zWV4AaABAg'], ['None', '2022-02-27T18:00:00Z', 'Ugxn_K9OOJDNBws5-4F4AaABAg'], ['None', '2022-02-25T15:30:07Z', 'Ugyyu4TXhDd32 ...
#                                              Reason                  Data  \
# 0                                 Electricity price  2021-05-25T20:10:48Z
# 1                                             Other  2021-05-04T16:00:31Z
# 2                                          EV price  2021-05-04T16:00:31Z
# 3                                              None  2021-10-10T07:45:02Z
# 4                                  Service problems  2022-01-10T09:40:46Z
# ...                                             ...                   ...
# 1221                                          Other  2021-11-24T14:00:11Z
# 1222  Charging infrastructure availability national  2021-11-24T14:00:11Z
# 1223                                  Charging time  2021-11-24T14:00:11Z
# 1224                                  Energy supply  2021-11-24T14:00:11Z
# 1225                                  Energy supply  2021-01-03T08:00:04Z
#
#                       Comment_ID
# 0     UgzmfkeUgGimgM30FQh4AaABAg
# 1     UgwUIBdvTpLvXHr5S5t4AaABAg
# 2     UgwUIBdvTpLvXHr5S5t4AaABAg
# 3     Ugx6x6UQB0IW0oR8wfR4AaABAg
# 4     UgwmzlwoVWwo4Tgj96J4AaABAg
# ...                          ...
# 1221  UgyiD_8JBaxNlvLjuB54AaABAg
# 1222  UgyiD_8JBaxNlvLjuB54AaABAg
# 1223  UgyiD_8JBaxNlvLjuB54AaABAg
# 1224  UgyiD_8JBaxNlvLjuB54AaABAg
# 1225  Ugy3EFOwftNmsTIxCux4AaABAg
#
# [1226 rows x 3 columns]

# %%
print(hurdles_df.loc[hurdles_df['Reason'] == "None"])

hurdles_df = hurdles_df.drop(hurdles_df[hurdles_df.Reason == "None"].index)
hurdles_df = hurdles_df.drop(hurdles_df[hurdles_df.Reason == "Sarcasm"].index)


print(hurdles_df)
# Out:
#      Reason                  Data                  Comment_ID
# 3      None  2021-10-10T07:45:02Z  Ugx6x6UQB0IW0oR8wfR4AaABAg
# 9      None  2020-07-15T07:03:15Z  Ugxez6h3F3z_Djzc3aJ4AaABAg
# 12     None  2020-08-18T17:19:32Z  UgzM-OjMzR4KwjIOVQV4AaABAg
# 14     None  2020-11-27T16:46:54Z  UgwRBdJbp_P0XItKuCh4AaABAg
# 16     None  2021-03-19T16:25:11Z  UgyZmhPRdBdn6LjFzMh4AaABAg
# ...     ...                   ...                         ...
# 1201   None  2021-12-12T12:06:40Z  UgxgsKHjxdjpQHVplIx4AaABAg
# 1207   None  2022-02-25T15:30:07Z  UgyDuFeoRRrmxeeezep4AaABAg
# 1211   None  2021-06-18T08:37:16Z  Ugz5U6IAvAJbXixMs014AaABAg
# 1212   None  2022-02-25T15:30:07Z  UgwbJFmsJF7sjoGA8yJ4AaABAg
# 1215   None  2020-12-01T11:30:03Z  UgyDfHrI01vvQEA0yc14AaABAg
#
# [522 rows x 3 columns]
#                                              Reason                  Data  \
# 0                                 Electricity price  2021-05-25T20:10:48Z
# 1                                             Other  2021-05-04T16:00:31Z
# 2                                          EV price  2021-05-04T16:00:31Z
# 4                                  Service problems  2022-01-10T09:40:46Z
# 5                                  Service problems  2022-01-10T09:40:46Z
# ...                                             ...                   ...
# 1221                                          Other  2021-11-24T14:00:11Z
# 1222  Charging infrastructure availability national  2021-11-24T14:00:11Z
# 1223                                  Charging time  2021-11-24T14:00:11Z
# 1224                                  Energy supply  2021-11-24T14:00:11Z
# 1225                                  Energy supply  2021-01-03T08:00:04Z
#
#                       Comment_ID
# 0     UgzmfkeUgGimgM30FQh4AaABAg
# 1     UgwUIBdvTpLvXHr5S5t4AaABAg
# 2     UgwUIBdvTpLvXHr5S5t4AaABAg
# 4     UgwmzlwoVWwo4Tgj96J4AaABAg
# 5     Ugyj9KU84hD_Pv3NECd4AaABAg
# ...                          ...
# 1221  UgyiD_8JBaxNlvLjuB54AaABAg
# 1222  UgyiD_8JBaxNlvLjuB54AaABAg
# 1223  UgyiD_8JBaxNlvLjuB54AaABAg
# 1224  UgyiD_8JBaxNlvLjuB54AaABAg
# 1225  Ugy3EFOwftNmsTIxCux4AaABAg
#
# [698 rows x 3 columns]

# %%
def f(row):
    reason = row['Reason']
    if reason == 'Charging infrastructure availability national' or reason == 'Charging infrastructure availability abroad' or reason == 'Charging infrastructure not working' or reason == 'Charging infrastructure location':
        val = 'Problems with the existing charging infrastructure'
    elif reason == 'Battery (environmental concerns)':
        val = 'Energy availability concerns/environmental concerns'
    elif reason == 'Selection of EVs':
        val = 'EV price/availability'
    elif reason == 'Energy supply':
        val = 'Energy availability concerns/environmental concerns'
    elif reason == 'Habbit':
        val = 'User habit'
    elif reason == 'Service problems' or reason == 'Car quality problems (Tesla)' or reason == 'Car software (VW)' or reason == 'Car quality problems (VW)' or reason == 'Car software (other)' or reason == 'Car software (Tesla)' or reason == 'Car quality problems (other)':
        val = 'Problems with the currently available EVs'
    elif reason == 'Tariff jungle':
        val = 'Problems with the existing charging infrastructure'
    elif reason == 'Charging time':
        val = 'Car charging time'
    elif reason == 'Used car (resell value)':
        val = 'EV price/availability'
    elif reason == 'Used car (availabilty)':
        val = 'EV price/availability'
    elif reason == 'EV price':
        val = 'EV price/availability'
    else:
        val = reason
    return val

hurdles_df['reason_flattened'] = hurdles_df.apply(f, axis=1)

# %%
plot_data = hurdles_df.groupby(['reason_flattened']).size().sort_values(ascending=False)
print(plot_data)
print(plot_data.index)

plt.figure(figsize=(15,15))

plt.pie(plot_data, labels=plot_data.index, autopct='%.0f%%',wedgeprops = {'linewidth': 1})
plt.show()
# Out:
# reason_flattened
# Problems with the existing charging infrastructure     142
# Problems with the currently available EVs              117
# Energy availability concerns/environmental concerns     97
# Other                                                   84
# EV price/availability                                   75
# Range anxiety                                           63
# Electricity price                                       54
# Car charging time                                       39
# User habit                                              27
# dtype: int64
# Index(['Problems with the existing charging infrastructure',
#        'Problems with the currently available EVs',
#        'Energy availability concerns/environmental concerns', 'Other',
#        'EV price/availability', 'Range anxiety', 'Electricity price',
#        'Car charging time', 'User habit'],
#       dtype='object', name='reason_flattened')

# %%
file = pd.read_json(work_dir + "/Comment/comments_with-sentiment&topics.json")

# %%
print(file["compound"])
file = file[(file['compound'] < 0.05)]
print(file["compound"])


mask = (file['comment'].str.len() > 50)
file = file.loc[mask]
# Out:
# 0         0.8883
# 1         0.7845
# 2        -0.7351
# 3        -0.2561
# 4         0.9940
#            ...
# 529296    0.0000
# 529297    0.8059
# 529298    0.0387
# 529299   -0.5187
# 529300    0.4019
# Name: compound, Length: 529301, dtype: float64
# 2        -0.7351
# 3        -0.2561
# 7        -0.6337
# 9         0.0000
# 10        0.0000
#            ...
# 529286   -0.5080
# 529291   -0.0754
# 529296    0.0000
# 529298    0.0387
# 529299   -0.5187
# Name: compound, Length: 207617, dtype: float64

# %%
print(file)
file['published'] = pd.to_datetime(file['published'])
df_2022 = file[(file['published'] > '2022-01-01') & (file['published'] < '2022-12-31')]
df_2021 = file[(file['published'] > '2021-01-01') & (file['published'] < '2021-12-31')]
df_2020 = file[(file['published'] > '2020-01-01') & (file['published'] < '2020-12-31')]
# Out:
#         level_0   index  table_id     video_id  job_x page       date  \
# 3             3       3     10064  kjwiFMxRotQ     85      2022-03-08
# 7             7       7     10068  kjwiFMxRotQ     85      2022-03-08
# 10           10      10     10071  kjwiFMxRotQ     85      2022-03-08
# 11           11      11     10072  kjwiFMxRotQ     85      2022-03-08
# 13           13      14     10075  kjwiFMxRotQ     85      2022-03-08
# ...         ...     ...       ...          ...    ...  ...        ...
# 529286   531812  562212    572273  W1MsL8Z8sIo    144      2022-03-15
# 529291   531817  562217    572278  W1MsL8Z8sIo    144      2022-03-15
# 529296   531822  562223    572284  W1MsL8Z8sIo    144      2022-03-15
# 529298   531824  562225    572286  W1MsL8Z8sIo    144      2022-03-15
# 529299   531825  562226    572287  W1MsL8Z8sIo    144      2022-03-15
#
#                 author  likes   published  ...  \
# 3                Ed Sa      0  2022-03-08  ...
# 7              Sylaina      0  2022-03-08  ...
# 10           Optum EBA      0  2022-03-08  ...
# 11            John Doe      1  2022-03-08  ...
# 13           Adi Heina      0  2022-03-08  ...
# ...                ...    ...         ...  ...
# 529286   All Inclusive      1  2021-08-05  ...
# 529291  Jürgen Binning      1  2021-08-03  ...
# 529296  Horst Bottesch      2  2021-07-30  ...
# 529298    n8flight2403      2  2021-07-30  ...
# 529299       Tim Taler      2  2021-07-30  ...
#
#                                                     title  \
# 3       Mein Elektro-Mercedes Werkstatt Termin: DESAST...
# 7       Mein Elektro-Mercedes Werkstatt Termin: DESAST...
# 10      Mein Elektro-Mercedes Werkstatt Termin: DESAST...
# 11      Mein Elektro-Mercedes Werkstatt Termin: DESAST...
# 13      Mein Elektro-Mercedes Werkstatt Termin: DESAST...
# ...                                                   ...
# 529286  100 % autark mit Strom aus der Photovoltaikanl...
# 529291  100 % autark mit Strom aus der Photovoltaikanl...
# 529296  100 % autark mit Strom aus der Photovoltaikanl...
# 529298  100 % autark mit Strom aus der Photovoltaikanl...
# 529299  100 % autark mit Strom aus der Photovoltaikanl...
#
#                     published_at                channel_id view_count  \
# 3      2022-02-25 15:30:07+00:00  UCiZnK4X73okItJqaCs2YDOQ     214027
# 7      2022-02-25 15:30:07+00:00  UCiZnK4X73okItJqaCs2YDOQ     214027
# 10     2022-02-25 15:30:07+00:00  UCiZnK4X73okItJqaCs2YDOQ     214027
# 11     2022-02-25 15:30:07+00:00  UCiZnK4X73okItJqaCs2YDOQ     214027
# 13     2022-02-25 15:30:07+00:00  UCiZnK4X73okItJqaCs2YDOQ     214027
# ...                          ...                       ...        ...
# 529286 2021-07-30 13:00:16+00:00  UCGoI004ZXiUb1NmY3zXBWTw      10251
# 529291 2021-07-30 13:00:16+00:00  UCGoI004ZXiUb1NmY3zXBWTw      10251
# 529296 2021-07-30 13:00:16+00:00  UCGoI004ZXiUb1NmY3zXBWTw      10251
# 529298 2021-07-30 13:00:16+00:00  UCGoI004ZXiUb1NmY3zXBWTw      10251
# 529299 2021-07-30 13:00:16+00:00  UCGoI004ZXiUb1NmY3zXBWTw      10251
#
#        like_count comment_count  job_y  id  valid  \
# 3           16048          4224      0   0  valid
# 7           16048          4224      0   0  valid
# 10          16048          4224      0   0  valid
# 11          16048          4224      0   0  valid
# 13          16048          4224      0   0  valid
# ...           ...           ...    ...  ..    ...
# 529286        317           109      0   0  valid
# 529291        317           109      0   0  valid
# 529296        317           109      0   0  valid
# 529298        317           109      0   0  valid
# 529299        317           109      0   0  valid
#
#                                           title_processed
# 3       mein elektro-mercedes werkstatt termin: desast...
# 7       mein elektro-mercedes werkstatt termin: desast...
# 10      mein elektro-mercedes werkstatt termin: desast...
# 11      mein elektro-mercedes werkstatt termin: desast...
# 13      mein elektro-mercedes werkstatt termin: desast...
# ...                                                   ...
# 529286  100 % autark mit strom aus der photovoltaikanl...
# 529291  100 % autark mit strom aus der photovoltaikanl...
# 529296  100 % autark mit strom aus der photovoltaikanl...
# 529298  100 % autark mit strom aus der photovoltaikanl...
# 529299  100 % autark mit strom aus der photovoltaikanl...
#
# [161918 rows x 31 columns]

# %%
print(df_2020.shape)
print(df_2021.shape)
print(df_2022.shape)

sample_2020 = df_2020.sample(n=1000)
sample_2021 = df_2021.sample(n=1000)
sample_2022 = df_2022.sample(n=1000)
# Out:
# (36897, 31)
# (104049, 31)
# (20006, 31)

# %%
sample_2020.to_csv('sample_2020.csv', index=False)
sample_2021.to_csv('sample_2021.csv', index=False)
sample_2022.to_csv('sample_2022.csv', index=False)

# %%
with open(work_dir + "/Comment/ah_20.json", encoding="utf8") as json_file:
    data = json.load(json_file)

data_list = []
i = 0
for entry in data:
    flatten_data = flatten(data[i])
    try:
        choice_0 = flatten_data["annotations_0_result_0_value_choices_0"]
    except:
        choice_0 = False
    try:
        choice_1 = flatten_data["annotations_0_result_0_value_choices_1"]
    except:
        choice_1 = False
    try:
        choice_2 = flatten_data["annotations_0_result_0_value_choices_2"]
    except:
        choice_2 = False
    try:
        choice_3 = flatten_data["annotations_0_result_0_value_choices_3"]
    except:
        choice_3 = False
    try:
        choice_4 = flatten_data["annotations_0_result_0_value_choices_4"]
    except:
        choice_4 = False
    try:
        choice_5 = flatten_data["annotations_0_result_0_value_choices_5"]
    except:
        choice_5 = False
    try:
        choice_6 = flatten_data["annotations_0_result_0_value_choices_6"]
    except:
        choice_6 = False
    
    if choice_0 is not False:
        temp_list = [choice_0, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_1 is not False:
        temp_list = [choice_1, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_2 is not False:
        temp_list = [choice_2, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_3 is not False:
        temp_list = [choice_3, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_4 is not False:
        temp_list = [choice_4, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_5 is not False:
        temp_list = [choice_5, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_6 is not False:
        temp_list = [choice_6, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    i = i + 1

# %%
print(len(data_list))
print(data_list)

ah_20_df = pd.DataFrame(data_list, columns = ['Reason', 'Data', 'Comment_ID'])
print(ah_20_df)
# Out:
# 261
# [['EV price/availability', '2020-07-15 07:03:15+00:00', 'UgzKZc1tig-T3SZWKWN4AaABAg'], ['EV price/availability', '2020-11-01 18:43:55+00:00', 'Ugwv_fl0KlfwqnPKBRh4AaABAg'], ['Range anxiety', '2020-09-05 03:30:01+00:00', 'UgzSvfs5GvgcZufmHgt4AaABAg'], ['None', '2020-07-12 19:34:33+00:00', 'Ugx3k02uWzB3Vk0jm3t4AaABAg'], ['None', '2020-12-25 08:09:11+00:00', 'UgzjWZC3uT88PrMmpN94AaABAg'], ['None', '2020-07-05 22:23:24+00:00', 'UgzjGkSQNY7KHFLZx654AaABAg'], ['Problems with the currently available EVs', '2020-07-28 16:00:15+00:00', 'Ugyq4NJosFdILAadvz54AaABAg'], ['Other', '2020-07-19 07:30:03+00:00', 'Ugwvv0FRKOxJCb9nD3x4AaABAg'], ['None', '2020-09-12 16:00:10+00:00', 'Ugy_fgnGizqv1hwDl7F4AaABAg'], ['Other', '2020-10-29 19:12:39+00:00', 'Ugx3g9_DQCEKmwWMPwd4AaABAg'], ['EV price/availability', '2020-09-23 14:59:33+00:00', 'Ugx2bIPgSz61f2kLRl54AaABAg'], ['Other', '2020-12-05 18:59:50+00:00', 'UgyKnVg50NQW7Zi3F814AaABAg'], ['EV price/availability', '2020-09-23 15:00:00+00:00', 'UgzeVy-5ke4eA3McwhN4AaABAg'], ['None', '2020-09-23 16:00:13+00:00', 'Ugyd9F0Ret1M-m4hCyh4AaABAg'], ['Problems with the currently available EVs', '2020-11-13 17:00:25+00:00', 'UgzVJo4B_MH_T9PDoKV4AaABAg'], ['Problems with the currently available EVs', '2020-07
gwrUowRY8gkLdc4kUJ4AaABAg'], ['User habbit', '2020-07-30 14:00:15+00:00', 'UgyWGKtw7QNrJPAujfd4AaABAg'], ['Other', '2020-07-30 14:00:15+00:00', 'UgyWGKtw7QNrJPAujfd4AaABAg'], ['Electricity price', '2020-08-05 08:53:01+00:00', 'UgwqX8OHv3GXN2G5Odx4AaABAg'], ['None', '2020-12-23 15:00:09+00:00', 'UgyvHxbJoPVT4IY_l2N4AaABAg'], ['None', '2020-10-26 16:30:01+00:00', 'UgxmqCtsAMiXfY-3Pnt4AaABAg'], ['Problems with the currently available EVs', '2020-10-06 16:46: ...
#                                                 Reason  \
# 0                                EV price/availability
# 1                                EV price/availability
# 2                                        Range anxiety
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 256                                              Other
# 257  Energy availability concerns/environmental con...
# 258                                               None
# 259                                              Other
# 260                              EV price/availability
#
#                           Data                  Comment_ID
# 0    2020-07-15 07:03:15+00:00  UgzKZc1tig-T3SZWKWN4AaABAg
# 1    2020-11-01 18:43:55+00:00  Ugwv_fl0KlfwqnPKBRh4AaABAg
# 2    2020-09-05 03:30:01+00:00  UgzSvfs5GvgcZufmHgt4AaABAg
# 3    2020-07-12 19:34:33+00:00  Ugx3k02uWzB3Vk0jm3t4AaABAg
# 4    2020-12-25 08:09:11+00:00  UgzjWZC3uT88PrMmpN94AaABAg
# ..                         ...                         ...
# 256  2020-09-01 16:00:08+00:00  UgzHEJM63qqrQtRBSIV4AaABAg
# 257  2020-07-30 05:30:01+00:00  UgzyqzLwVpB8_bAufdd4AaABAg
# 258  2020-10-27 16:30:05+00:00  UgzWdr_ryoOsokzz87B4AaABAg
# 259  2020-12-10 15:30:03+00:00  UgxfDMmaAPt0KX77-Et4AaABAg
# 260  2020-08-25 17:00:26+00:00  Ugx8dGUR89xCzfYWtAB4AaABAg
#
# [261 rows x 3 columns]

# %%
with open(work_dir + "/Comment/ah_21.json", encoding="utf8") as json_file:
    data = json.load(json_file)

data_list = []
i = 0
for entry in data:
    flatten_data = flatten(data[i])
    try:
        choice_0 = flatten_data["annotations_0_result_0_value_choices_0"]
    except:
        choice_0 = False
    try:
        choice_1 = flatten_data["annotations_0_result_0_value_choices_1"]
    except:
        choice_1 = False
    try:
        choice_2 = flatten_data["annotations_0_result_0_value_choices_2"]
    except:
        choice_2 = False
    try:
        choice_3 = flatten_data["annotations_0_result_0_value_choices_3"]
    except:
        choice_3 = False
    try:
        choice_4 = flatten_data["annotations_0_result_0_value_choices_4"]
    except:
        choice_4 = False
    try:
        choice_5 = flatten_data["annotations_0_result_0_value_choices_5"]
    except:
        choice_5 = False
    try:
        choice_6 = flatten_data["annotations_0_result_0_value_choices_6"]
    except:
        choice_6 = False
    
    if choice_0 is not False:
        temp_list = [choice_0, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_1 is not False:
        temp_list = [choice_1, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_2 is not False:
        temp_list = [choice_2, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_3 is not False:
        temp_list = [choice_3, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_4 is not False:
        temp_list = [choice_4, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_5 is not False:
        temp_list = [choice_5, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_6 is not False:
        temp_list = [choice_6, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    i = i + 1

# %%
print(len(data_list))
print(data_list)

ah_21_df = pd.DataFrame(data_list, columns = ['Reason', 'Data', 'Comment_ID'])
print(ah_21_df)
# Out:
# 268
# [['Problems with the currently available EVs', '2021-06-03 14:00:33+00:00', 'UgwboR_XMxh4XIKx0H14AaABAg'], ['Problems with the currently available EVs', '2021-03-30 15:00:14+00:00', 'UgympheN_CUWot3w08l4AaABAg'], ['None', '2021-04-28 09:30:10+00:00', 'UgwWY1m2jOc0-T7ui6x4AaABAg'], ['None', '2021-03-28 08:00:03+00:00', 'UgxfeO1XUuQfIe5S34x4AaABAg'], ['None', '2021-03-11 15:30:00+00:00', 'Ugw26Z6vvBlTrZnLBmp4AaABAg'], ['None', '2021-07-06 08:42:36+00:00', 'UgyihhBSczqBr2oC2lJ4AaABAg'], ['Other', '2021-09-28 13:15:00+00:00', 'UgwF9cfoGQIC2DgDp2V4AaABAg'], ['Energy availability concerns/environmental concerns', '2021-09-28 13:15:00+00:00', 'UgwF9cfoGQIC2DgDp2V4AaABAg'], ['EV price/availability', '2021-04-09 16:00:14+00:00', 'Ugz4QVGpqCqv7cCOGTB4AaABAg'], ['None', '2021-04-15 16:00:30+00:00', 'UgzePWtD8HR1DpXoAYB4AaABAg'], ['None', '2021-03-11 16:03:20+00:00', 'UgxqCnStbgShdMa2Y554AaABAg'], ['EV price/availability', '2021-12-07 17:15:38+00:00', 'Ugwj8qg1HS4YXkX7GG54AaABAg'], ['None', '2021-04-12 15:48:16+00:00', 'Ugy5weCfoXIHJ1RRGU54AaABAg'], ['Other', '2021-09-12 08:02:32+00:00', 'UgzXok-kbxuxuq5xWfl4AaABAg'], ['Other', '2021-09-22 13:30:03+00:00', 'Ugzay6q0mehm_ohqcDl4AaABAg'], ['None', '2021-11-11 18:30:20+00:00', 'UgwKzBwrLlnSlf3-uPZ4AaABAg'], ['Other', '2021-09-05 16:00:07+00:00', 'UgxKe9MTPLKliQRaraV4AaABAg'], ['Other', '2021-01-16 11:46:22+00:00', 'UgxwTb0c7W41lL_sYvh4AaABAg'], ['User habbit', '2021-09-05 08:21:30+00:00', 'UgyGOULeqyHwMEjntaF4AaABAg'], ['Other', '2021-09-05 08:21:30+00:00', 'UgyGOULeqyHwMEjntaF4AaABAg'], ['Other', '2021-01-21 16:08:57+00:00', 'UgyqOkYAW_rH3YEqhX14AaABAg'], ['Problems with the existing charging infrastructure', '2021-11-26 15:00:24+00:00', 'UgwQy1_lgyTSvxKtAj94AaABAg'], ['Energy availability concerns/environmental concerns', '2021-10-29 09:29:48+00:00', 'UgyUj4cbvsRrOXz1SJB4AaABAg'], ['Other', '2021-09-29 22:00:15+00:00', 'Ugw7U-KNvzDrj2s5hEN4AaABAg'], ['Problems with the currently available EVs', '2021-06-07 17:05:13+00:00', 'UgwMIK7W4yKGnkURQ-N4AaABAg'], ['EV price/availability', '2021-03-11 14:41:11+00:00', 'UgxJXJLEOySNejZUuCJ4AaABAg'], ['Other', '2021-05-01 07:52:48+00:00', 'UgyS2kiSgY6jHTki8VZ4AaABAg'], ['Problems with the existing charging infr
#
#                      Comment_ID
# 0    UgwboR_XMxh4XIKx0H14AaABAg
# 1    UgympheN_CUWot3w08l4AaABAg
# 2    UgwWY1m2jOc0-T7ui6x4AaABAg
# 3    UgxfeO1XUuQfIe5S34x4AaABAg
# 4    Ugw26Z6vvBlTrZnLBmp4AaABAg
# ..                          ...
# 263  UgxBOPSg0YXe04GihfN4AaABAg
# 264  UgxlHgpRWMdq-h3oi5l4AaABAg
# 265  UgydoXgV3z0UQ4-_eX94AaABAg
# 266  UgyE40qMGnXAb6NYGwt4AaABAg
# 267  UgwA9TwXTcMnvLFWrp54AaABAg
#
# [268 rows x 3 columns]

# %%
with open(work_dir + "/Comment/ah_22.json", encoding="utf8") as json_file:
    data = json.load(json_file)

data_list = []
i = 0
for entry in data:
    flatten_data = flatten(data[i])
    try:
        choice_0 = flatten_data["annotations_0_result_0_value_choices_0"]
    except:
        choice_0 = False
    try:
        choice_1 = flatten_data["annotations_0_result_0_value_choices_1"]
    except:
        choice_1 = False
    try:
        choice_2 = flatten_data["annotations_0_result_0_value_choices_2"]
    except:
        choice_2 = False
    try:
        choice_3 = flatten_data["annotations_0_result_0_value_choices_3"]
    except:
        choice_3 = False
    try:
        choice_4 = flatten_data["annotations_0_result_0_value_choices_4"]
    except:
        choice_4 = False
    try:
        choice_5 = flatten_data["annotations_0_result_0_value_choices_5"]
    except:
        choice_5 = False
    try:
        choice_6 = flatten_data["annotations_0_result_0_value_choices_6"]
    except:
        choice_6 = False
    
    if choice_0 is not False:
        temp_list = [choice_0, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_1 is not False:
        temp_list = [choice_1, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)

    if choice_2 is not False:
        temp_list = [choice_2, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_3 is not False:
        temp_list = [choice_3, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_4 is not False:
        temp_list = [choice_4, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_5 is not False:
        temp_list = [choice_5, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    if choice_6 is not False:
        temp_list = [choice_6, flatten_data["data_published_at"], flatten_data["data_comment_id"]]
        data_list.append(temp_list)
    i = i + 1

# %%
print(len(data_list))
print(data_list)

ah_22_df = pd.DataFrame(data_list, columns = ['Reason', 'Data', 'Comment_ID'])
print(ah_22_df)
# Out:
# 274
# [['Other', '2022-02-18 15:00:32+00:00', 'UgwvDPWAkI1pJxPfOIl4AaABAg'], ['Other', '2021-10-29 09:29:48+00:00', 'UgwsqFXCUu_myEQuZRR4AaABAg'], ['Problems with the existing charging infrastructure', '2022-02-11 15:00:28+00:00', 'UgycXp7ITidEBx-rozZ4AaABAg'], ['Range anxiety', '2022-02-11 15:00:28+00:00', 'UgycXp7ITidEBx-rozZ4AaABAg'], ['Other', '2022-02-16 07:00:10+00:00', 'UgyZTzxVpNAvjnlNzAx4AaABAg'], ['Problems with the currently available EVs', '2022-02-16 07:00:10+00:00', 'UgyZTzxVpNAvjnlNzAx4AaABAg'], ['None', '2022-02-12 08:00:08+00:00', 'UgzI_nxvT9mKpGyC3AF4AaABAg'], ['Other', '2021-04-08 18:17:20+00:00', 'UgwlF7ddRwUuAwymfLh4AaABAg'], ['Range anxiety', '2021-04-08 18:17:20+00:00', 'UgwlF7ddRwUuAwymfLh4AaABA
aukfSA81-Et4AaABAg'], ['None', '2022-02-11 16:01:05+00:00', 'UgyC92BlzrHefH19WK94AaABAg'], ['None', '2022-01-05 19:00:30+00:00', 'UgyIrIhFtvDg1YXk_714AaABAg'], ['Other', '2022-01-14 15:00:35+00:00', 'Ugy1hjdPGWJ2qfXcvYx4AaABAg'], ['EV price/availability', '2021-08-23 14:00:00+00:00', 'UgxgaePjDW_3oeKuaKB4AaABAg'], ['None', '2022-01-11 16:55:24+00:00', 'UgxVrABR3oR8v5WRL6t4AaABAg'], ['Other', '2022-01-20 16:13:47+00:00', 'Ugx3vPEr2yN6LaU9gWp4AaABAg'], ['None', '2022-02-08 16:00:04+00:00', 'UgwPtEJ3eXMHkTLGMJF4AaABAg'], ['Problems with the existing charging infrastructure', '2021-12-30 12:17:59+00:00', 'Ugx7MuuTH1IaxuFt63h4AaABAg'], ['Energy availability concerns/environmental concerns', '2021-12-30 12:17:59+00:00', 'Ugx7MuuTH1IaxuFt63h4AaABAg'], ['None', '2022-01-23 08:30:02+00:00', 'Ugy133kVWkyn_Dm-CdN4AaABAg'], ['Problems with the existing charging infrastructure', '2022-02-11 17:29:35+00:00', 'UgwjCc8C9FPwIhK-a1d4AaABAg'], ['None', '2021-12-09 10:16:15+00:00', 'Ugw0ip6tmpfaRu5bf8h4AaABAg'], ['None', '2022-01-12 17:00:05+00: ...
#                                                 Reason  \
# 0                                                Other
# 1                                                Other
# 2    Problems with the existing charging infrastruc...
# 3                                        Range anxiety
# 4                                                Other
# ..                                                 ...
# 269                                               None
# 270                              EV price/availability
# 271                                               None
# 272                                              Other
# 273          Problems with the currently available EVs
#
#                           Data                  Comment_ID
# 0    2022-02-18 15:00:32+00:00  UgwvDPWAkI1pJxPfOIl4AaABAg
# 1    2021-10-29 09:29:48+00:00  UgwsqFXCUu_myEQuZRR4AaABAg
# 2    2022-02-11 15:00:28+00:00  UgycXp7ITidEBx-rozZ4AaABAg
# 3    2022-02-11 15:00:28+00:00  UgycXp7ITidEBx-rozZ4AaABAg
# 4    2022-02-16 07:00:10+00:00  UgyZTzxVpNAvjnlNzAx4AaABAg
# ..                         ...                         ...
# 269  2022-02-27 17:12:19+00:00  Ugz1fh6KcnY5tEsZC9R4AaABAg
# 270  2020-08-04 14:00:08+00:00  UgxyLzlL5X4nH42CSm94AaABAg
# 271  2022-01-03 17:00:13+00:00  Ugy9dKyFMRUcpyVu6SB4AaABAg
# 272  2021-02-28 17:00:13+00:00  Ugw3X_huS_EUAnGv_Y14AaABAg
# 273  2022-01-11 16:00:25+00:00  UgwcXU2PXv_ZTHM8UIF4AaABAg
#
# [274 rows x 3 columns]

# %%
print(ah_22_df.loc[ah_22_df['Reason'] == "None"])

ah_22_none = ah_22_df.loc[ah_22_df['Reason'] == "None"]
print(ah_22_none.shape)

ah_22_df = ah_22_df.drop(ah_22_df[ah_22_df.Reason == "None"].index)


print(ah_22_df)
# Out:
#     Reason                       Data                  Comment_ID
# 6     None  2022-02-12 08:00:08+00:00  UgzI_nxvT9mKpGyC3AF4AaABAg
# 17    None  2021-11-04 19:18:28+00:00  UgxXby2KkJcxO711lcB4AaABAg
# 19    None  2022-02-23 14:00:11+00:00  UgyiVwkUygUJyLIJmYF4AaABAg
# 21    None  2022-02-27 10:34:16+00:00  UgxXNd3Xqtqayvq15a94AaABAg
# 24    None  2022-02-16 20:37:35+00:00  Ugyp87UWHglZ2T_Utnl4AaABAg
# ..     ...                        ...                         ...
# 258   None  2022-01-31 15:00:36+00:00  UgwiZHxRA0_qK9GKiNl4AaABAg
# 261   None  2022-01-22 20:51:54+00:00  UgzAVBhkoSE2qrl5v254AaABAg
# 266   None  2022-02-10 19:29:08+00:00  Ugyo70E14gTUKWEczJN4AaABAg
# 269   None  2022-02-27 17:12:19+00:00  Ugz1fh6KcnY5tEsZC9R4AaABAg
# 271   None  2022-01-03 17:00:13+00:00  Ugy9dKyFMRUcpyVu6SB4AaABAg
#
# [93 rows x 3 columns]
# (93, 3)
#                                                 Reason  \
# 0                                                Other
# 1                                                Other
# 2    Problems with the existing charging infrastruc...
# 3                                        Range anxiety
# 4                                                Other
# ..                                                 ...
# 267                              EV price/availability
# 268          Problems with the currently available EVs
# 270                              EV price/availability
# 272                                              Other
# 273          Problems with the currently available EVs
#
#                           Data                  Comment_ID
# 0    2022-02-18 15:00:32+00:00  UgwvDPWAkI1pJxPfOIl4AaABAg
# 1    2021-10-29 09:29:48+00:00  UgwsqFXCUu_myEQuZRR4AaABAg
# 2    2022-02-11 15:00:28+00:00  UgycXp7ITidEBx-rozZ4AaABAg
# 3    2022-02-11 15:00:28+00:00  UgycXp7ITidEBx-rozZ4AaABAg
# 4    2022-02-16 07:00:10+00:00  UgyZTzxVpNAvjnlNzAx4AaABAg
# ..                         ...                         ...
# 267  2022-02-11 16:00:09+00:00  Ugz3XywsIZYl-wi7dMR4AaABAg
# 268  2022-02-25 15:30:07+00:00  UgyfjebXKS5BSsXiuwN4AaABAg
# 270  2020-08-04 14:00:08+00:00  UgxyLzlL5X4nH42CSm94AaABAg
# 272  2021-02-28 17:00:13+00:00  Ugw3X_huS_EUAnGv_Y14AaABAg
# 273  2022-01-11 16:00:25+00:00  UgwcXU2PXv_ZTHM8UIF4AaABAg
#
# [181 rows x 3 columns]

# %%
print(ah_21_df.loc[ah_21_df['Reason'] == "None"])

ah_21_none = ah_21_df.loc[ah_21_df['Reason'] == "None"]
print(ah_21_none.shape)

ah_21_df = ah_21_df.drop(ah_21_df[ah_21_df.Reason == "None"].index)


print(ah_21_df)
# Out:
#     Reason                       Data                  Comment_ID
# 2     None  2021-04-28 09:30:10+00:00  UgwWY1m2jOc0-T7ui6x4AaABAg
# 3     None  2021-03-28 08:00:03+00:00  UgxfeO1XUuQfIe5S34x4AaABAg
# 4     None  2021-03-11 15:30:00+00:00  Ugw26Z6vvBlTrZnLBmp4AaABAg
# 5     None  2021-07-06 08:42:36+00:00  UgyihhBSczqBr2oC2lJ4AaABAg
# 9     None  2021-04-15 16:00:30+00:00  UgzePWtD8HR1DpXoAYB4AaABAg
# ..     ...                        ...                         ...
# 252   None  2021-08-29 11:45:05+00:00  Ugxh1pnlPQRlNSSF3VF4AaABAg
# 261   None  2021-07-04 09:30:05+00:00  Ugzpi7KVCJuisSFE4Gp4AaABAg
# 263   None  2021-08-12 16:00:42+00:00  UgxBOPSg0YXe04GihfN4AaABAg
# 265   None  2021-01-14 06:00:16+00:00  UgydoXgV3z0UQ4-_eX94AaABAg
# 267   None  2021-04-12 18:50:12+00:00  UgwA9TwXTcMnvLFWrp54AaABAg
#
# [100 rows x 3 columns]
# (100, 3)
#                                                 Reason  \
# 0            Problems with the currently available EVs
# 1            Problems with the currently available EVs
# 6                                                Other
# 7    Energy availability concerns/environmental con...
# 8                                EV price/availability
# ..                                                 ...
# 259  Energy availability concerns/environmental con...
# 260                                        User habbit
# 262                                              Other
# 264                                  Electricity price
# 266          Problems with the currently available EVs
#
#                           Data                  Comment_ID
# 0    2021-06-03 14:00:33+00:00  UgwboR_XMxh4XIKx0H14AaABAg
# 1    2021-03-30 15:00:14+00:00  UgympheN_CUWot3w08l4AaABAg
# 6    2021-09-28 13:15:00+00:00  UgwF9cfoGQIC2DgDp2V4AaABAg
# 7    2021-09-28 13:15:00+00:00  UgwF9cfoGQIC2DgDp2V4AaABAg
# 8    2021-04-09 16:00:14+00:00  Ugz4QVGpqCqv7cCOGTB4AaABAg
# ..                         ...                         ...
# 259  2021-06-15 15:59:07+00:00  UgxQffLT-PQtkU0y5Fd4AaABAg
# 260  2021-07-12 11:01:25+00:00  Ugz8maBCP4PqYsEmJHR4AaABAg
# 262  2021-02-03 10:15:01+00:00  UgzIVbrh2PKvBB07S4V4AaABAg
# 264  2021-06-14 16:30:04+00:00  UgxlHgpRWMdq-h3oi5l4AaABAg
# 266  2021-02-03 21:49:51+00:00  UgyE40qMGnXAb6NYGwt4AaABAg
#
# [168 rows x 3 columns]

# %%
print(ah_20_df.loc[ah_20_df['Reason'] == "None"])

ah_20_none = ah_20_df.loc[ah_20_df['Reason'] == "None"]
print(ah_20_none.shape)

ah_20_df = ah_20_df.drop(ah_20_df[ah_20_df.Reason == "None"].index)


print(ah_20_df)
# Out:
#     Reason                       Data                  Comment_ID
# 3     None  2020-07-12 19:34:33+00:00  Ugx3k02uWzB3Vk0jm3t4AaABAg
# 4     None  2020-12-25 08:09:11+00:00  UgzjWZC3uT88PrMmpN94AaABAg
# 5     None  2020-07-05 22:23:24+00:00  UgzjGkSQNY7KHFLZx654AaABAg
# 8     None  2020-09-12 16:00:10+00:00  Ugy_fgnGizqv1hwDl7F4AaABAg
# 13    None  2020-09-23 16:00:13+00:00  Ugyd9F0Ret1M-m4hCyh4AaABAg
# ..     ...                        ...                         ...
# 248   None  2020-07-02 20:43:06+00:00  UgwFixLegqOwcvEpLhx4AaABAg
# 251   None  2020-12-17 18:25:46+00:00  Ugyqx0gYyTg34b5iGjx4AaABAg
# 253   None  2020-10-18 08:00:04+00:00  Ugx0s-NrE81MwZBkOeN4AaABAg
# 254   None  2020-11-26 10:45:00+00:00  UgymB9zTWQOiOxBdbKR4AaABAg
# 258   None  2020-10-27 16:30:05+00:00  UgzWdr_ryoOsokzz87B4AaABAg
#
# [106 rows x 3 columns]
# (106, 3)
#                                                 Reason  \
# 0                                EV price/availability
# 1                                EV price/availability
# 2                                        Range anxiety
# 6            Problems with the currently available EVs
# 7                                                Other
# ..                                                 ...
# 255  Energy availability concerns/environmental con...
# 256                                              Other
# 257  Energy availability concerns/environmental con...
# 259                                              Other
# 260                              EV price/availability
#
#                           Data                  Comment_ID
# 0    2020-07-15 07:03:15+00:00  UgzKZc1tig-T3SZWKWN4AaABAg
# 1    2020-11-01 18:43:55+00:00  Ugwv_fl0KlfwqnPKBRh4AaABAg
# 2    2020-09-05 03:30:01+00:00  UgzSvfs5GvgcZufmHgt4AaABAg
# 6    2020-07-28 16:00:15+00:00  Ugyq4NJosFdILAadvz54AaABAg
# 7    2020-07-19 07:30:03+00:00  Ugwvv0FRKOxJCb9nD3x4AaABAg
# ..                         ...                         ...
# 255  2020-07-02 20:43:06+00:00  UgwQypq14PYJhxZf1s54AaABAg
# 256  2020-09-01 16:00:08+00:00  UgzHEJM63qqrQtRBSIV4AaABAg
# 257  2020-07-30 05:30:01+00:00  UgzyqzLwVpB8_bAufdd4AaABAg
# 259  2020-12-10 15:30:03+00:00  UgxfDMmaAPt0KX77-Et4AaABAg
# 260  2020-08-25 17:00:26+00:00  Ugx8dGUR89xCzfYWtAB4AaABAg
#
# [155 rows x 3 columns]

# %%
def f(row):
    reason = row['Reason']
    if reason == 'User habbit':
        val = 'User habit'
    else:
        val = reason
    return val

ah_20_df['Reason'] = ah_20_df.apply(f, axis=1)
ah_21_df['Reason'] = ah_20_df.apply(f, axis=1)
ah_22_df['Reason'] = ah_20_df.apply(f, axis=1)

# %%
plot_data = ah_20_df.groupby(['Reason']).size()

plot_data = plot_data.sort_values(ascending=False)

plt.figure(figsize=(15,15))

plt.pie(plot_data, labels=plot_data.index, autopct='%.0f%%',wedgeprops = {'linewidth': 1})
plt.show()

# %%
plot_data = ah_21_df.groupby(['Reason']).size()
print(plot_data.index)
plot_data = plot_data.sort_values(ascending=False)

plt.figure(figsize=(15,15))

plt.pie(plot_data, labels=plot_data.index, autopct='%.0f%%',wedgeprops = {'linewidth': 1})
plt.show()
# Out:
# Index(['EV price/availability', 'Electricity price',
#        'Energy availability concerns/environmental concerns', 'Other',
#        'Problems with the currently available EVs',
#        'Problems with the existing charging infrastructure', 'Range anxiety',
#        'User habit'],
#       dtype='object', name='Reason')

# %%
plot_data = ah_22_df.groupby(['Reason']).size()
print(plot_data.index)
plot_data = plot_data.sort_values(ascending=False)

plt.figure(figsize=(15,15))

plt.pie(plot_data, labels=plot_data.index, autopct='%.0f%%',wedgeprops = {'linewidth': 1})
plt.show()
# Out:
# Index(['Car charging time', 'EV price/availability', 'Electricity price',
#        'Energy availability concerns/environmental concerns', 'Other',
#        'Problems with the currently available EVs',
#        'Problems with the existing charging infrastructure', 'Range anxiety',
#        'User habit'],
#       dtype='object', name='Reason')
